# %%
import pandas as pd


data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/transformed/model train & test data(0408)/train_data_after_vector(0408).csv")

data_row
# Out:
#        Unnamed: 0         0         1         2         3         4         5  \
# 0           42295 -0.047089  0.063892  0.029231 -0.010113 -0.006478 -0.076092
# 1            3190 -0.055536  0.138560  0.006196 -0.017301  0.018906 -0.033579
# 2           40118 -0.029811  0.010970  0.123542 -0.005753  0.035553  0.000369
# 3           30102 -0.062099  0.084755  0.060447 -0.022535  0.018325 -0.001904
# 4           24082  0.049052  0.044712 -0.022597 -0.039976 -0.086668 -0.081158
# ...           ...       ...       ...       ...       ...       ...       ...
# 45095       31613 -0.017996  0.081561  0.049061 -0.024363 -0.062396 -0.066412
# 45096       22795 -0.012324  0.092338  0.017695 -0.046255  0.005313 -0.036136
# 45097       10408 -0.044434  0.051099  0.018821 -0.061765 -0.002669 -0.024412
# 45098       42669  0.026813  0.061191  0.083230 -0.037458 -0.067816 -0.057853
# 45099       42255 -0.078083  0.068086  0.085566 -0.032933 -0.064185 -0.019818
#
#               6         7         8  ...       375       376       377  \
# 0      0.099555 -0.001815  0.008044  ... -0.048174  0.008701 -0.011126
# 1      0.093570  0.029771 -0.028367  ...  0.056634  0.035820  0.001394
# 2      0.150513 -0.013701  0.043224  ...  0.041866  0.077456  0.049570
# 3      0.120448  0.085908 -0.100444  ...  0.003087  0.041487 -0.030792
# 4      0.060701  0.073576 -0.008297  ... -0.008109 -0.009057 -0.003918
# ...         ...       ...       ...  ...       ...       ...       ...
# 45095  0.043858  0.003921 -0.006983  ...  0.031472  0.006121  0.011798
# 45096  0.050817 -0.019606 -0.062418  ...  0.017938  0.014461 -0.015199
# 45097  0.153289 -0.004021  0.023836  ...  0.006949 -0.046395 -0.052662
# 45098  0.070095  0.035106  0.000051  ...  0.017808 -0.003950  0.033453
# 45099  0.106469 -0.009045 -0.000450  ...  0.044883 -0.005370  0.037237
#
#             378       379       380       381       382       383  predict
# 0      0.056443  0.023786  0.074422  0.072273  0.000286 -0.001965        1
# 1      0.036563 -0.001339  0.048955  0.059002 -0.068693 -0.040135        1
# 2     -0.016544  0.028134  0.119930  0.078847  0.045365 -0.024858        0
# 3     -0.019727  0.030926  0.038755  0.084055 -0.051373 -0.034596        1
# 4      0.028707  0.004766 -0.045225  0.034536 -0.008039  0.003858        0
# ...         ...       ...       ...       ...       ...       ...      ...
# 45095  0.087703  0.028996  0.102621  0.048586 -0.115112  0.028416        1
# 45096  0.028363 -0.040143  0.071181  0.089119 -0.080809  0.027789        1
# 45097 -0.036260 -0.038702  0.079753  0.034723 -0.034148  0.042189        0
# 45098  0.053071 -0.017053  0.038842  0.020965 -0.079598  0.020110        1
# 45099  0.020618  0.000284  0.058568  0.067188 -0.085538 -0.059315        0
#
# [45100 rows x 386 columns]

# %%
data_row.drop(columns=['Unnamed: 0'],inplace=True)

# %%
y_train=pd.DataFrame(data=(data_row['predict']))

# %%
y_train
# Out:
#        predict
# 0            1
# 1            1
# 2            0
# 3            1
# 4            0
# ...        ...
# 45095        1
# 45096        1
# 45097        0
# 45098        1
# 45099        0
#
# [45100 rows x 1 columns]

# %%
data=data_row

# %%
data_row.drop(columns=['predict'],inplace=True)

# %%
data_row
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0
# ...         ...       ...       ...       ...       ...       ...       ...
# 45095 -0.017996  0.081561  0.049061 -0.024363 -0.062396 -0.066412  0.043858
# 45096 -0.012324  0.092338  0.017695 -0.046255  0.005313 -0.036136  0.050817
# 45097 -0.044434  0.051099  0.018821 -0.061765 -0.002669 -0.024412  0.153289
# 45098  0.026813  0.061191  0.083230 -0.037458 -0.067816 -0.057853  0.070095
# 45099 -0.078083  0.068086  0.085566 -0.032933 -0.064185 -0.019818  0.106469
#
#               7         8         9  ...       374       375       376  \
# 0     -0.001815  0.008044 -0.057395  ... -0.020264 -0.048174  0.008701
# 1      0.029771 -0.028367 -0.031059  ...  0.019837  0.056634  0.035820
# 2     -0.013701  0.043224 -0.047796  ...  0.063105  0.041866  0.077456
# 3      0.085908 -0.100444 -0.062563  ...  0.020486  0.003087  0.041487
# 4      0.073576 -0.008297 -0.053323  ... -0.008716 -0.008109 -0.009057
# ...         ...       ...       ...  ...       ...       ...       ...
# 45095  0.003921 -0.006983  0.011597  ...  0.032094  0.031472  0.006121
# 45096 -0.019606 -0.062418  0.012101  ...  0.068868  0.017938  0.014461
# 45097 -0.004021  0.023836 -0.006379  ... -0.018625  0.006949 -0.046395
# 45098  0.035106  0.000051 -0.003941  ...  0.015094  0.017808 -0.003950
# 45099 -0.009045 -0.000450 -0.022211  ...  0.058092  0.044883 -0.005370
#
#             377       378       379       380       381       382       383
# 0     -0.011126  0.056443  0.023786  0.074422  0.072273  0.000286 -0.001965
# 1      0.001394  0.036563 -0.001339  0.048955  0.059002 -0.068693 -0.040135
# 2      0.049570 -0.016544  0.028134  0.119930  0.078847  0.045365 -0.024858
# 3     -0.030792 -0.019727  0.030926  0.038755  0.084055 -0.051373 -0.034596
# 4     -0.003918  0.028707  0.004766 -0.045225  0.034536 -0.008039  0.003858
# ...         ...       ...       ...       ...       ...       ...       ...
# 45095  0.011798  0.087703  0.028996  0.102621  0.048586 -0.115112  0.028416
# 45096 -0.015199  0.028363 -0.040143  0.071181  0.089119 -0.080809  0.027789
# 45097 -0.052662 -0.036260 -0.038702  0.079753  0.034723 -0.034148  0.042189
# 45098  0.033453  0.053071 -0.017053  0.038842  0.020965 -0.079598  0.020110
# 45099  0.037237  0.020618  0.000284  0.058568  0.067188 -0.085538 -0.059315
#
# [45100 rows x 384 columns]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (45100, 384)
# (45100, 1)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(x_train[:]['0'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x_test=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/transformed/target/after vector/test data/x_target.csv")
y_test=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/transformed/target/after vector/test data/y_target.csv")

# %%
x_test.drop(columns=['Unnamed: 0'],inplace=True)
y_test.drop(columns=['Unnamed: 0'],inplace=True)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (1195, 384)
# (1195, 1)

# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

import os

# %%
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test) # test set에는 transform만 사용하기

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (45100, 384)
# (1195, 384)

# %%
x_train = tf.cast(x_train, tf.float32)
x_test = tf.cast(x_test, tf.float32)

# %%
y_train = y_train.astype(bool)
y_test = y_test.astype(bool)

# %%
x_train = tf.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_test = tf.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
#y_test=tf.reshape(y_test,(y_test.shape[0],y_test.shape[1],1))
print('변경된 차원 정보 :',x_train.shape)
# Out:
# 변경된 차원 정보 : (45100, 384, 1)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (45100, 384, 1)
# (1195, 384, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dense, Input, TimeDistributed, Flatten
from keras.layers.convolutional import Conv1D ,MaxPooling1D
from keras.layers import Bidirectional
from keras.layers import LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, TimeDistributed, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.regularizers import l2

# %%
model = Sequential()
model.add(Bidirectional(LSTM(30, return_sequences=True, kernel_regularizer=l2(0.001)), input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(20, return_sequences=True, kernel_regularizer=l2(0.001))))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(10, return_sequences=True, kernel_regularizer=l2(0.001))))
model.add(TimeDistributed(Dense(10, activation='relu')))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid', kernel_initializer='uniform'))

# 최적화 알고리즘과 손실 함수 설정
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping과 Model Checkpoint 적용
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)

# 모델 요약 출력
model.summary()

#model.fit(x_train, y_train, validation_split=0.2, epochs=100, callbacks=[early_stopping])
# Out:
# 2024-04-09 11:23:26.402810: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:23:26.403625: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:23:26.404179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:23:26.465841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-09 11:23:26.491562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:23:26.492314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:23:26.493130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:23:26.578824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:23:26.579468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:23:26.579954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:23:26.635617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-09 11:23:26.662124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:23:26.663077: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:23:26.663827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:23:26.758463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:23:26.759017: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:23:26.759500: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:23:26.810224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-09 11:23:26.827471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:23:26.827965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:23:26.828352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (None, 384, 60)          7680
#  nal)
#
#  dropout_2 (Dropout)         (None, 384, 60)           0
#
#  bidirectional_4 (Bidirectio  (None, 384, 40)          12960
#  nal)
#
#  dropout_3 (Dropout)         (None, 384, 40)           0
#
#  bidirectional_5 (Bidirectio  (None, 384, 20)          4080
#  nal)
#
#  time_distributed_1 (TimeDis  (None, 384, 10)          210
#  tributed)
#
#  flatten_1 (Flatten)         (None, 3840)              0
#
#  dense_3 (Dense)             (None, 1)                 3841
#
# =================================================================
# Total params: 28,771
# Trainable params: 28,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
training_record = model.fit(x_train, y_train,
                    epochs=100,
                    batch_size=400,
                    verbose=1,
                    validation_split=0.2,
                    callbacks=[early_stopping],
                    shuffle=True)
# Out:
# Epoch 1/100
# 91/91 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.6422
# 2024-04-09 11:25:22.920711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:25:22.922252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:25:22.923066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:25:23.001475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-09 11:25:23.026955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:25:23.027809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:25:23.028616: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:25:23.237050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:25:23.238025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:25:23.238756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:25:23.315642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-09 11:25:23.341805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:25:23.342471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:25:23.343050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:25:23.431063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:25:23.431723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:25:23.432321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-09 11:25:23.499544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-09 11:25:23.524383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-09 11:25:23.525676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-09 11:25:23.526286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 91/91 [==============================] - 77s 838ms/step - loss: 0.6758 - accuracy: 0.6422 - val_loss: 0.5559 - val_accuracy: 0.7390
# Epoch 2/100
# 91/91 [==============================] - 65s 718ms/step - loss: 0.4974 - accuracy: 0.7869 - val_loss: 0.4379 - val_accuracy: 0.8134
# Epoch 3/100
# 91/91 [==============================] - 66s 719ms/step - loss: 0.3954 - accuracy: 0.8444 - val_loss: 0.3549 - val_accuracy: 0.8636
# Epoch 4/100
# 91/91 [==============================] - 65s 715ms/step - loss: 0.3304 - accuracy: 0.8757 - val_loss: 0.3100 - val_accuracy: 0.8831
# Epoch 5/100
# 91/91 [==============================] - 71s 781ms/step - loss: 0.2962 - accuracy: 0.8889 - val_loss: 0.2780 - val_accuracy: 0.8950
# 91/91 [==============================] - 77s 851ms/step - loss: 0.1032 - accuracy: 0.9631 - val_loss: 0.1125 - val_accuracy: 0.9568
# Epoch 66/100
# 91/91 [==============================] - 75s 829ms/step - loss: 0.1020 - accuracy: 0.9637 - val_loss: 0.1095 - val_accuracy: 0.9598
# Epoch 67/100
# 91/91 [==============================] - 76s 831ms/step - loss: 0.1023 - accuracy: 0.9625 - val_loss: 0.1121 - val_accuracy: 0.9588
# Epoch 68/100
# 91/91 [==============================] - 73s 798ms/step - loss: 0.1025 - accuracy: 0.9625 - val_loss: 0.1103 - val_accuracy: 0.9591
# Epoch 69/100
# 91/91 [==============================] - 77s 844ms/step - loss: 0.1003 - accuracy: 0.9642 - val_loss: 0.1099 - val_accuracy: 0.9604
# Epoch 70/100
# 91/91 [==============================] - 72s 791ms/step - loss: 0.0998 - accuracy: 0.9635 - val_loss: 0.1161 - val_accuracy: 0.9561
# Epoch 71/100
# 91/91 [==============================] - 71s 783ms/step - loss: 0.0999 - accuracy: 0.9638 - val_loss: 0.1079 - val_accuracy: 0.9596
# Epoch 72/100
# 91/91 [==============================] - 81s 892ms/step - loss: 0.0994 - accuracy: 0.9644 - val_loss: 0.1205 - val_accuracy: 0.9523
# Epoch 73/100
# 91/91 [==============================] - 78s 859ms/step - loss: 0.0959 - accuracy: 0.9654 - val_loss: 0.1078 - val_accuracy: 0.9601
# Epoch 74/100
# 91/91 [==============================] - 72s 797ms/step - loss: 0.0980 - accuracy: 0.9642 - val_loss: 0.1098 - val_accuracy: 0.9579
# Epoch 75/100
# 91/91 [==============================] - 73s 802ms/step - loss: 0.1006 - accuracy: 0.9637 - val_loss: 0.1124 - val_accuracy: 0.9578
# Epoch 76/100
# 91/91 [==============================] - 73s 803ms/step - loss: 0.0979 - accuracy: 0.9650 - val_loss: 0.1150 - val_accuracy: 0.9564
# Epoch 77/100
# 91/91 [==============================] - 77s 851ms/step - loss: 0.0967 - accuracy: 0.9648 - val_loss: 0.1085 - val_accuracy: 0.9606
# Epoch 78/100
# 91/91 [==============================] - 74s 809ms/step - loss: 0.0965 - accuracy: 0.9652 - val_loss: 0.1062 - val_accuracy: 0.9610
# Epoch 79/100
# 91/91 [==============================] - 75s 821ms/step - loss: 0.0943 - accuracy: 0.9664 - val_loss: 0.1173 - val_accuracy: 0.9589
# Epoch 80/100
# 91/91 [==============================] - 77s 850ms/step - loss: 0.0951 - accuracy: 0.9661 - val_loss: 0.1071 - val_accuracy: 0.9601
# Epoch 81/100
# 91/91 [==============================] - 75s 822ms/step - loss: 0.0930 - accuracy: 0.9663 - val_loss: 0.1059 - val_accuracy: 0.9596
# Epoch 82/100
# 91/91 [==============================] - 78s 854ms/step - loss: 0.0917 - accuracy: 0.9670 - val_loss: 0.1102 - val_accuracy: 0.9591
# Epoch 83/100
# 91/91 [==============================] - 76s 837ms/step - loss: 0.0922 - accuracy: 0.9669 - val_loss: 0.1125 - val_accuracy: 0.9598
# Epoch 84/100
# 91/91 [==============================] - 80s 874ms/step - loss: 0.0952 - accuracy: 0.9652 - val_loss: 0.1078 - val_accuracy: 0.9600
# Epoch 85/100
# 91/91 [==============================] - 73s 805ms/step - loss: 0.0906 - accuracy: 0.9670 - val_loss: 0.1033 - val_accuracy: 0.9611
# Epoch 86/100
# 91/91 [==============================] - 76s 833ms/step - loss: 0.0909 - accuracy: 0.9665 - val_loss: 0.1190 - val_accuracy: 0.9520
# Epoch 87/100
# 91/91 [==============================] - 76s 837ms/step - loss: 0.0919 - accuracy: 0.9669 - val_loss: 0.1173 - val_accuracy: 0.9583
# Epoch 88/100
# 91/91 [==============================] - 78s 862ms/step - loss: 0.0918 - accuracy: 0.9663 - val_loss: 0.1019 - val_accuracy: 0.9629
# Epoch 89/100
# 91/91 [==============================] - 73s 803ms/step - loss: 0.0895 - accuracy: 0.9678 - val_loss: 0.1038 - val_accuracy: 0.9634
# Epoch 90/100
# 91/91 [==============================] - 80s 876ms/step - loss: 0.0882 - accuracy: 0.9690 - val_loss: 0.1075 - val_accuracy: 0.9554
# Epoch 91/100
# 91/91 [==============================] - 77s 846ms/step - loss: 0.0917 - accuracy: 0.9669 - val_loss: 0.1064 - val_accuracy: 0.9630
# Epoch 92/100
# 91/91 [==============================] - 86s 943ms/step - loss: 0.0871 - accuracy: 0.9681 - val_loss: 0.1011 - val_accuracy: 0.9626
# Epoch 93/100
# 91/91 [==============================] - 72s 789ms/step - loss: 0.0937 - accuracy: 0.9657 - val_loss: 0.1075 - val_accuracy: 0.9615
# Epoch 94/100
# 91/91 [==============================] - 71s 784ms/step - loss: 0.0869 - accuracy: 0.9688 - val_loss: 0.1076 - val_accuracy: 0.9596
# Epoch 95/100
# 91/91 [==============================] - 69s 763ms/step - loss: 0.0888 - accuracy: 0.9682 - val_loss: 0.1007 - val_accuracy: 0.9623
# Epoch 96/100
# 91/91 [==============================] - 67s 735ms/step - loss: 0.0885 - accuracy: 0.9675 - val_loss: 0.1017 - val_accuracy: 0.9629
# Epoch 97/100
# 91/91 [==============================] - 70s 765ms/step - loss: 0.0862 - accuracy: 0.9687 - val_loss: 0.1030 - val_accuracy: 0.9623
# Epoch 98/100
# 91/91 [==============================] - 70s 765ms/step - loss: 0.0861 - accuracy: 0.9689 - val_loss: 0.1013 - val_accuracy: 0.9591
# Epoch 99/100
# 91/91 [==============================] - 70s 770ms/step - loss: 0.0861 - accuracy: 0.9688 - val_loss: 0.1019 - val_accuracy: 0.9608
# Epoch 100/100
# 91/91 [==============================] - 68s 751ms/step - loss: 0.0867 - accuracy: 0.9688 - val_loss: 0.1041 - val_accuracy: 0.9596

# %%
model.save('BiLSTM_model.h5')

# %%
fig, ax = plt.subplots()
plt.plot(training_record.history["loss"], label="Training Loss")
plt.plot(training_record.history["val_loss"], label="Validation Loss")
plt.legend()
fig.suptitle("Loss")
plt.show()

# %%
model.save('bilstm_model.h5')

# %%
print(x_test.shape)
# Out:
# (1195, 384, 1)

# %%
print(y_test.shape)
# Out:
# (1195, 1)

# %%
pred=model.predict(x_test)
# Out:
# 38/38 [==============================] - 1s 31ms/step

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def precision_recall_curve_plot(y_test,pred):
    precisions, recalls,thresholds = precision_recall_curve(y_test,pred)
    
    plt.figure(figsize=(8,6))
    threshold_index = thresholds.shape[0]
    plt.plot(thresholds,precisions[0:threshold_index],'r--',label='precision')
    plt.plot(thresholds,recalls[0:threshold_index],label='recall')
    
    start,end = plt.xlim()
    plt.xticks(np.around(np.arange(start,end,0.001),2))
    
    plt.xlabel('Threshold value')
    plt.ylabel('precision and recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test,pred)

# %%
precisions, recalls,thresholds = precision_recall_curve(y_test,pred)

# %%
print(len(recalls))
print(len(precisions))
print(len(thresholds))
# Out:
# 1193
# 1193
# 1192

# %%
import numpy as np

# %%
# convert to f score
fscore = (2 * precisions * recalls) / (precisions + recalls)
# locate the index of the largest f score
ix = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
# Out:
# Best Threshold=0.937732, F-Score=nan
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_6109/1821508222.py:2: RuntimeWarning: invalid value encountered in divide
#   fscore = (2 * precisions * recalls) / (precisions + recalls)

# %%
thresholds_fit=1-thresholds[ix]

# %%
thresholds_fit
# Out:
# 0.06226837635040283

# %%
np.array(pred[:50])
# Out:
# array([[3.82936656e-01],
#        [3.33691761e-02],
#        [2.17139046e-03],
#        [3.53829848e-04],
#        [5.58282621e-03],
#        [4.82472358e-03],
#        [1.21517899e-03],
#        [8.37855488e-02],
#        [1.55204479e-02],
#        [1.83686893e-02],
#        [6.30841434e-01],
#        [8.51028191e-04],
#        [1.30887581e-02],
#        [1.77639499e-02],
#        [2.88478106e-01],
#        [1.79791974e-03],
#        [1.52671506e-04],
#        [1.43395783e-02],
#        [7.09363297e-02],
#        [9.26941913e-03],
#        [1.75170868e-03],
#        [7.14904368e-02],
#        [4.37408239e-01],
#        [1.27382621e-01],
#        [1.01065636e-01],
#        [6.27153814e-02],
#        [2.11530402e-01],
#        [8.01320828e-04],
#        [1.53956498e-04],
#        [4.90890294e-02],
#        [2.51628808e-03],
#        [5.39693341e-04],
#        [1.33555641e-05],
#        [2.15850933e-03],
#        [3.34648020e-03],
#        [4.83148993e-04],
#        [7.14269467e-03],
#        [1.02197319e-01],
#        [1.16321770e-02],
#        [5.60147734e-03],
#        [1.10687775e-04],
#        [4.77949344e-03],
#        [3.74647003e-04],
#        [1.43480459e-02],
#        [2.04622261e-02],
#        [1.60054807e-02],
#        [2.62647197e-02],
#        [7.39546120e-01],
#        [3.07948627e-02],
#        [3.53121519e-04]], dtype=float32)

# %%
print(recalls[692])
# Out:
# 0.298

# %%
thresholds
# Out:
# array([1.9122981e-06, 3.2772841e-06, 1.0038017e-05, ..., 9.9960560e-01,
#        9.9981236e-01, 9.9996907e-01], dtype=float32)

# %%
pred
# Out:
# array([[0.38293666],
#        [0.03336918],
#        [0.00217139],
#        ...,
#        [0.01704186],
#        [0.0458377 ],
#        [0.00411507]], dtype=float32)

# %%
print(thresholds_fit)
# Out:
# 0.06226837635040283

# %%
y_pred=pred.reshape(-1)
threshold = thresholds_fit
pred = (y_pred >= threshold)

# %%
pred=pd.DataFrame(pred)

# %%
pred
# Out:
#           0
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 1190  False
# 1191  False
# 1192  False
# 1193  False
# 1194  False
#
# [1195 rows x 1 columns]

# %%
y_test=np.array(y_test['predict'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 y_test=np.array(y_test['predict'])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
y_test
# Out:
# array([ True,  True, False, ..., False, False,  True])

# %%
accuracy_test= accuracy_score(y_test, pred)
print(f'Accuracy: {accuracy_test}')
# Out:
# Accuracy: 0.4610878661087866
