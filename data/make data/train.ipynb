# %%
import pandas as pd

data=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/No fishing/train data/No fishing_train.csv",index_col=0)
data_ab=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/train data/fishing_train.csv",index_col=0)

# %%
data
# Out:
#                                              sentence  predict
# 10346                             네, 접수는 선착순으로 마감됩니다.        0
# 23368                               무엇 때문에 질문 해주시는거죠?        0
# 20067  입주신청서와 추천서, 급여내역서 외 기타 서류를 갖고 홈페이지에서 신청하면 됩니다.        0
# 8268                          최근6개월이내 여권사진과 수수료필요합니다.        0
# 4856                                   예외되는 업종이 있습니다.        0
# ...                                               ...      ...
# 2298                        온라인에서는 무료민원으로 발급 가능 하십니다.        0
# 22149                              예.또 도와 드릴사항이 있을까요?        0
# 11960                            현재까지 노래, 밴드, 댄스 입니다.        0
# 21363                                  네. 무엇을 도와드릴까요?        0
# 1427                                       네, 그렇습니다.         0
#
# [24267 rows x 2 columns]

# %%
data_ab
# Out:
#                                                 sentence  predict
# 7941    그리고 6번에 보시면은 기타 추가적인 문의 사항이 있을 경우엔 담당 검사인 저한테...        2
# 4380                '변호사 선임해주시고 연락을 주시면은 저희 직원이 파견나간다고요'        1
# 7779                                                 '예'        2
# 3812    '그게 지금 고객센터로 넘어가는게 좀 서류가 늦게 들어가서 확인이 안되실수도 있으세요'        1
# 3235                                          '무슨 데이터가?'        2
# ...                                                  ...      ...
# 357                                                   예금        2
# 11680                             '아 그 뭐를 말씀드리면 된다 그랬죠?'        2
# 2325                                                 '네'        1
# 9836                                           마약 사건이라던가        2
# 1013                                     '예 업무 다 보셨습니까?'        2
#
# [18160 rows x 2 columns]

# %%
data=pd.concat([data,data_ab])

# %%
data
# Out:
#                                              sentence  predict
# 10346                             네, 접수는 선착순으로 마감됩니다.        0
# 23368                               무엇 때문에 질문 해주시는거죠?        0
# 20067  입주신청서와 추천서, 급여내역서 외 기타 서류를 갖고 홈페이지에서 신청하면 됩니다.        0
# 8268                          최근6개월이내 여권사진과 수수료필요합니다.        0
# 4856                                   예외되는 업종이 있습니다.        0
# ...                                               ...      ...
# 357                                                예금        2
# 11680                          '아 그 뭐를 말씀드리면 된다 그랬죠?'        2
# 2325                                              '네'        1
# 9836                                        마약 사건이라던가        2
# 1013                                  '예 업무 다 보셨습니까?'        2
#
# [42427 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data.to_csv("origin train data.csv")
