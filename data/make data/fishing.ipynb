# %%
import pandas as pd 

data1=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/labeled/대출사기(1).csv")
data2=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/labeled/수사기관(2).csv")

data1.drop(columns=['Unnamed: 0'],inplace=True)
data2.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data=pd.concat([data1,data2])

# %%
data
# Out:
#                                                sentence  predict
# 0                                     '어저께 통화했던 최영환입니다'        1
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...        1
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'        1
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'        1
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...        1
# ...                                                 ...      ...
# 8427                   '그 본인 말고도 180명이 넘게 연루된 사건이다 보니까'        2
# 8428   '찾아오시는 분들이 많기 때문에 저희가 일방적으로 오라고 말씀드릴 수 없기 때문에...        2
# 8429                   '그러면은 문자로 관련 내용 간단하게 요약해서 보내주세요'        2
# 8430                           '예 그 본인 자택으로 서류 보내드릴게요.'        2
# 8431   '그 문자 말고 그 확인하시고 읽어보신 다음에 이해 안 가는 부분 있으시면 다시 ...        2
#
# [11909 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data
# Out:
#                                                sentence  predict
# 2709                                   '그럼 오늘 끝나는 거예요.'        2
# 7035                              저가 항공권을 판매한다고 올려놓구요.'        2
# 5626                                 '네에 앞서 말씀 드렸을 거예요'        2
# 3137   '당일로도 가능하시고 다만 위임 처리하실 경우에는 이제 뭐 수수료는 저희가 대신 ...        1
# 1767                                  '안 들리시면은 안 들립니다.'        2
# ...                                                 ...      ...
# 2493                           '왜냐면 솔직히 이게 보이스피싱 같기도 하고        1
# 4366                 '뭐 본인 사건에 대한 공이 일 날이니까 이거를 확인하셔야지'        2
# 1701                                     '전부 숫자 조합이고요.'        2
# 7433   '그 대전 쪽에서 거주하시는데 이게 등본상의 거주지나 실 거주지가 유지가 되시는 ...        2
# 4813                   '네 그러면 손가락 한 마디 정도 밑으로 내려오셔가지고요'        2
#
# [11909 rows x 2 columns]

# %%
test_data=pd.DataFrame(data.iloc[:300])

# %%
test_data
# Out:
#                                                sentence  predict
# 2709                                   '그럼 오늘 끝나는 거예요.'        2
# 7035                              저가 항공권을 판매한다고 올려놓구요.'        2
# 5626                                 '네에 앞서 말씀 드렸을 거예요'        2
# 3137   '당일로도 가능하시고 다만 위임 처리하실 경우에는 이제 뭐 수수료는 저희가 대신 ...        1
# 1767                                  '안 들리시면은 안 들립니다.'        2
# ...                                                 ...      ...
# 7369                   '원활한 녹취 진행을 위해서 한 가지 좀 안내해 드리자면'        2
# 5928                                   '어 그리고 요지 4번 보시면        2
# 972    '어차피 저는 수사관이기 때문에 저는 본인한테 사건 고지를 해드리고 이 부분에 대...        2
# 6685                                     국가 수사기관인 저희 검찰        2
# 8195   '어 이렇게 여쭤보는 이유는 박성재라는 사람이 얼마 전에 수사과에서 금융 사기혐의...        2
#
# [300 rows x 2 columns]

# %%
train_data=pd.DataFrame(data.iloc[300:])

# %%
train_data
# Out:
#                                                sentence  predict
# 5597   '네 일단 그럼 본인이 대출 받기 위해서 전화 받으신 내용에 대해 설명하게 설명을...        2
# 4631   '왜냐면 그 자금에 있어서 뭐 국가 안전 코드 부여된 것도 아니고 아무런 조치된 ...        2
# 307                              '마지막 거래하시면 하셔서 대략적으로.'        2
# 1693                                        '저희가 이렇게 해라        1
# 6                                    '네 성함은 OOO님 맞으시죠?'        2
# ...                                                 ...      ...
# 2493                           '왜냐면 솔직히 이게 보이스피싱 같기도 하고        1
# 4366                 '뭐 본인 사건에 대한 공이 일 날이니까 이거를 확인하셔야지'        2
# 1701                                     '전부 숫자 조합이고요.'        2
# 7433   '그 대전 쪽에서 거주하시는데 이게 등본상의 거주지나 실 거주지가 유지가 되시는 ...        2
# 4813                   '네 그러면 손가락 한 마디 정도 밑으로 내려오셔가지고요'        2
#
# [11609 rows x 2 columns]

# %%
train_data.to_csv("fishing_train.csv")
test_data.to_csv("fishing_test.csv")
