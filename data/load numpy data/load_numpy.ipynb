# %%
import numpy as np

import pandas as pd

# %%
origin2=np.load("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/n-gram/original/original_2gram_embedding.npy",allow_pickle=True)

# %%
origin2=origin2.reshape(-2,1)

# %%
origin2
# Out:
# array([[array([[-0.02122848480939865, 0.026077324524521828, 0.009656284004449844,
#                 ..., -0.027962258085608482, -0.041764963418245316,
#                 0.011550678871572018],
#                [-0.054531630128622055, -8.973391959443688e-05,
#                 0.010427700355648994, ..., -0.06198064982891083,
#                 0.0048723844811320305, -0.018615983426570892],
#                [-0.09660033881664276, 0.020401692017912865, -0.00769561855122447,
#                 ..., -0.009773477911949158, -0.02843763865530491,
#                 0.0440041683614254],
#                ...,
#                [-0.03927575796842575, 0.05051718279719353, 0.05944078043103218,
#                 ..., -0.01802988164126873, -0.038714710623025894,
#                 0.006016470026224852],
#                [-0.09601008147001266, 0.02685827948153019, -0.02746639773249626,
#                 ..., 0.001847796724177897, -0.10888586938381195,
#                 0.062407881021499634],
# ...
